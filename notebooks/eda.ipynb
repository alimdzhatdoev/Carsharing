# %% [markdown]
# # EDA: демо-данные каршеринга
#
# Краткий разведочный анализ. Основной воспроизводимый пайплайн — скрипты `scripts/generate_demo_data.py`, `scripts/train.py`.
#
# Запуск из корня репозитория после установки зависимостей.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parent if (Path.cwd().name == "notebooks") else Path.cwd()
csv_path = root / "data" / "raw" / "trips_demo.csv"
df = pd.read_csv(csv_path)
df.head()

# %%
df["target_class"].value_counts(normalize=True)

# %%
df.isna().mean().sort_values(ascending=False).head(10)
